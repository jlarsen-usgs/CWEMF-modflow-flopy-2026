# %% [markdown]
# ## Python overview and refersher
#
# In this overview and refresher session we will review important concepts in Python that will be used throughout the rest of the workshop.
#
# This notebook is a general overview of the common functions and types we use in Python.
#
# First let's consider three ways that we can interact with Python:
#    1. Through a command-line session
#    2. Using an IDE like VSCode or pyCharm
#    3. Using a jupyter notebook like this one

# %%
print('hello world')

# %% [markdown]
# ### python as a calculator
#
# Python can be used to perform basic arithmetic operations. (note: in a jupyter notebook like this one, shift-enter evaluates the code)

# %% [markdown]
# ### Variables and Types
#
# Variable names in Python can contain alphanumerical characters `a-z`, `A-Z`, `0-9` and some special characters like `_`. Normal variable names must start with a letter.
#
# By convention, variable names start with a lower-case letter, and Class (object) names start with a capital letter.
#
# #### Assignment
#
# Assigning values to a variable is done using the `=` operator in Python. Python is a dynamically typed language, so we do not need to specify the type of variable when we create one.
#
# Assigning a value to a variable name creates the variable.

# %% [markdown]
# And type conversion is possible when appropriate for the data

# %% [markdown]
# ### Strings
#
# Grouping characters together creates strings

# %% [markdown]
# Using square brackets (`[]`) we can get values of the string based on their position

# %% [markdown]
# We can also add strings together

# %% [markdown]
# And for comparisons, it is often important to match case, so we can cast to upper or lower case.

# %% [markdown]
# String formatting "f" strings

# %% [markdown]
# ### Lists
#
# There are a few ways to group values in Python. The most basic way is with a list, defined by `[]` brackets and comma-delimited

# %% [markdown]
# Note python uses zero based referencing (like C, C++). Using square brackets we can investigate the contents of a list (slice it!).

# %% [markdown]
# We can also add variables/values to a list using the `.append()` and `.extend()` methods

# %% [markdown]
# We can also remove items from a list using the `.pop()` method

# %% [markdown]
# ### Tuples
#
# Tuples have a similar construction as a `list`. A `tuple` is defined using regular parentheses (`()`). The key difference is that tuples are immutable.

# %% [markdown]
# what happens when we try to change values in a tuple?

# %% [markdown]
# ### Dictionaries
#
# Dictionaries are also like lists, except that each element is a key-value pair. The syntax for dictionaries is `{key1: value1, ....}`

# %%
params = {
    "p1": 1,
    "p2": 1,
    "p3": 2,
    "p4": 3,
    "p5": 5
}

# %% [markdown]
# We can obtain the keys seperately from their values

# %% [markdown]
# We can also just get the values

# %% [markdown]
# ### Loops
#
# In Python, loops can be programmed in a number of different ways. The most common way is the `for` loop, which is used to iterate over objects such as lists. The basic syntax is

# %% [markdown]
# The `for` loop iterates over the elements of the supplied list, and executes the containing block for each element.

# %% [markdown]
# #### An quick aside on indentation
#
# The level of indentation defines code blocks without requiring a symbol of word to close a block or a loop. Commonly, identation in Python is done using tabs, but a casual standard is also four spaces.

# %% [markdown]
# The `range()` and `enumerate()` objects with looping.

# %% [markdown]
# ### Conditionals
#
# Python's conditional syntax uses the keywords `if`, `elif` (else-if), `else` and follow the same indentation rules as loops:

# %% [markdown]
# ### Paths
#
# Often we want to read files and do something with the data in those files when we develop a script. Python has a built-in package called `pathlib` that helps us construct paths to files and folders

# %%
from pathlib import Path

# %%
pth = Path(".")

# %% [markdown]
# We can also append to an existing path using "/"

# %% [markdown]
# We can use paths to point to files and open/read/write them with the `open()` statement. Let's open `friends.txt` from the `data/python_refresher` folder

# %% [markdown]
# ### importing additional functionality
#
# Python has a large base of community development and many useful features need to be imported seperately from the core functionality. Here are a few examples on how to import useful tools

# %% [markdown]
# ### Working with array based data (numpy!)
#
# The package numpy (numerical python) allows us to work with array and vector based data and perform mathematical operations on that data. It is a very powerful library that allows for fast and complex mathematical operations. This package underpins many scientific applications in Python.

# %%
import numpy as np

# %% [markdown]
# Create an array of zeros and ones

# %% [markdown]
# Doing math on an array

# %% [markdown]
# Doing math on only part of the array

# %% [markdown]
# Flattening and reshaping an array

# %% [markdown]
# Writing data to file

# %% [markdown]
# Reading data from a file

# %% [markdown]
# **some useful numpy functions:** `np.where`, `np.linspace`, `np.arange`, `np.min/max nanmin/nanmax`

# %% [markdown]
# ### Working with delimited data like `.csv` data
#
# The pandas package in Python is used to read in tabular data like you'd find in a CSV file, excel worksheet, or tab (and/or space) delimited file. Let's load one up.

# %%
import pandas as pd
data_pth = Path("../data/python_refresher")
nwis_sites = data_pth / "site_info.csv"

# %% [markdown]
# Filtering data, let's get only the Groundwater sites

# %% [markdown]
# Adding a new column to the dataframe

# %% [markdown]
# Doing math

# %% [markdown]
# writing tabular data to file

# %% [markdown]
# **Now let's filter and write the SW sites to file**

# %% [markdown]
# #### Grouping data using groupby

# %% [markdown]
# ### merging and concatanating data

# %% [markdown]
# Build a couple of dataframes with info from the class and let's merge them in different ways

# %% [markdown]
# And let's concatenate two dataframes

# %% [markdown]
# ### Loading shapefile data
#
# Geopandas allows us to load and work with shapefile data in a pandas dataframe. There are a lot of powerful geospatial operations we can do with these dataframes, but we are going to just cover the absolute basics and see some more useful examples later in this workshop.

# %%
import geopandas as gpd

shp_file = data_pth / "sagehen_nhd.shp"

gdf = gpd.read_file(shp_file)
gdf

# %% [markdown]
# plot the geodataframe

# %% [markdown]
# add an attribute to the geodataframe

# %% [markdown]
# write the geodataframe to a new shapefile

# %% [markdown]
# Dissolving data

# %% [markdown]
# ### Plotting data using matplotlib
#
# Matplotlib is one of the main plotting libraries in Python and it has a lot of underlying capabilities. The matplotlib user examples is the best resource for finding recipies to create figures [https://matplotlib.org/stable/gallery/index.html](https://matplotlib.org/stable/gallery/index.html).
#
# In this example we'll show some very common applications of matplotlib:
#    - `plt.plot()` for timeseries data
#    - `plt.scatter()` for scatter plots
#    - `plt.imshow()` to visualize array data
#
# Additional visualization examples are scattered throughout the upcoming notebooks as well.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Resources
#
# This was a quick overview of basic functionality that is commonly used in model development. For a more thourough handling of these capabilities please take a look at the [Python-for-hydrology](https://doi-usgs.github.io/python-for-hydrology/latest/part0.html#) course materials.
